# %% [markdown]
# # Tool_Kit
# Este projeto tem como objetivo reunir as principais bibliotecas python utilizadas na área da Ciência de Dados e desenvolver um tutorial prático de como utilizar seus recursos
#
# Principais Bibliotecas Utilizadas:
# * Scikit Learn
# * Pandas
# * Pandas Profiling
# * Statsmodels
# * Matplotlib
# * seaborn

# %%
from tool_kit import *

# %%
titanic = load_database(name='titanic')

# %%
null_map(titanic)

# %%
Train_Test_Dataset = train_test(under_sample(titanic,target='survived',target_values=[0,1]),target='survived')

# %%
balanceado = under_sample(titanic,target='survived',target_values=[0,1])

# %%
x_train,y_train,x_test,y_test = train_test(balanceado,target ='survived')

# %%
treino_dot = train_test(titanic,target='survived',dot_map=True)

# %%
box_plot(titanic,target='age')
